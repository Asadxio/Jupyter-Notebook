# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/alias/Desktop/Admission_Predict.csv.xls")

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.['GRE Score'].max
# Out:
#   File "C:\Users\alias\AppData\Local\Temp\ipykernel_10304\3893941168.py", line 1
#     df.['GRE Score'].max
#        ^
# SyntaxError: invalid syntax

# %%
df.plot("GRE Score")
# Out:
# <AxesSubplot:xlabel='GRE Score'>

# %%
df["GRE Score"].plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
df["GRE Score"].plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["GRE Score"].plot(kind ='box')
# Out:
# <AxesSubplot:>

# %%
df["GRE Score"].plot(kind ='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df["GRE Score"].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df["GRE Score"].plot(kind ='area')
# Out:
# <AxesSubplot:>

# %%
df["GRE Score"].plot(kind ='line')
# Out:
# <AxesSubplot:>

# %%
df["GRE Score"].plot(kind ='box')
# Out:
# <AxesSubplot:>

# %%
df["GRE Score"].plot(kind ='line')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='scatter',x="GRE Score",y="TOEFL Score")
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='TOEFL Score'>

# %%
df["GRE Score"].plot(kind ='pie')
# Out:
# <AxesSubplot:ylabel='GRE Score'>

# %%
df["GRE Score"].plot(kind ='line')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Matplotlib

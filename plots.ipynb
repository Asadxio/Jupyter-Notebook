# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/alias/Desktop/Admission_Predict.csv.xls")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %% [markdown]
# #EDA

# %%
df['GRE Score']
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 395    324
# 396    325
# 397    330
# 398    312
# 399    333
# Name: GRE Score, Length: 400, dtype: int64

# %%
df['GRE Score'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["GRE Score"])
# Out:
# (array([ 5., 28., 35., 39., 64., 54., 68., 51., 31., 25.]),
#  array([290., 295., 300., 305., 310., 315., 320., 325., 330., 335., 340.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["GRE Score"])
# Out:
# (array([ 5., 28., 35., 39., 64., 54., 68., 51., 31., 25.]),
#  array([290., 295., 300., 305., 310., 315., 320., 325., 330., 335., 340.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["GRE Score"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1707864bb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17079d9a160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1707864b850>],
#  'medians': [<matplotlib.lines.Line2D at 0x17079d9a700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17079d9a9d0>],
#  'means': []}

# %%
df['GRE Score'].min()
# Out:
# 290

# %%
df['GRE Score'].max()
# Out:
# 340

# %%
df['GRE Score'].describe()
# Out:
# count    400.000000
# mean     316.807500
# std       11.473646
# min      290.000000
# 25%      308.000000
# 50%      317.000000
# 75%      325.000000
# max      340.000000
# Name: GRE Score, dtype: float64

# %%
plt.errorbar(df['GRE Score'],df['TOEFL Score'])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Out:
#   File "C:\Users\alias\AppData\Local\Temp\ipykernel_6780\1677195695.py", line 1
#     right scude
#           ^
# SyntaxError: invalid syntax

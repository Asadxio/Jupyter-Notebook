# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.title("Asad's Data")
plt.ylabel("This is y")
plt.xlabel("This is x")
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.plot([2,3,4],[2,6,8])
plt.title("Asad's Data")
plt.ylabel("This is y")
plt.xlabel("This is x")
plt.show()

# %%
from matplotlib import pyplot as plt

style.use('ggplot')
x=[1,5,4]
y=[23,45,89]
x2=[3,7,3]
y2=[5,8,9]

plt.plot(x,y)
plt.plot(x2,y2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7844\261640405.py in <module>
#       1 from matplotlib import pyplot as plt
#       2
# ----> 3 style.use('ggplot')
#       4 x=[1,5,4]
#       5 y=[23,45,89]
#
# NameError: name 'style' is not defined
